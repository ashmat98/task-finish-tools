# %%
from beep.utils import beep

# %%
beep()
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/ogg;base64,..." type="audio/ogg" />
#                     Your browser does not support the audio element.
#                 </audio>
